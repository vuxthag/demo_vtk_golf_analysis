# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()

api_key = os.getenv('OPENAI_API_KEY')

print("="*60)
print("🔑 API KEY INFO")
print("="*60)
print(f"Key first 30 chars: {api_key[:30] if api_key else 'NOT FOUND'}...")
print(f"Key last 10 chars: ...{api_key[-10:] if api_key else 'NOT FOUND'}")
print()

if api_key:
    try:
        client = OpenAI(api_key=api_key)
        
        # Test với model RẺ NHẤT
        print("🧪 Testing with gpt-3.5-turbo (cheapest)...")
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": "Hi"}],
            max_tokens=5
        )
        print(f"✅ SUCCESS! Response: {response.choices[0].message.content}")
        print(f"✅ This account WORKS!")
        
    except Exception as e:
        print(f"❌ ERROR: {e}")
        
        if "429" in str(e) or "quota" in str(e).lower():
            print("\n💡 DIAGNOSIS: Account ran out of credits!")
            print("   → Add payment method at: https://platform.openai.com/account/billing")
        elif "401" in str(e):
            print("\n💡 DIAGNOSIS: Invalid API key!")
        elif "rate_limit" in str(e).lower():
            print("\n💡 DIAGNOSIS: Rate limited - wait 1 minute")

print("\n" + "="*60)
# Out:
# ...
# 🔑 API KEY INFO
# ...
# Key first 30 chars: sk-proj-3xqlySp_HUmENveW19y6Hp...
# Key last 10 chars: ...v26suq9s4A
#
# 🧪 Testing with gpt-3.5-turbo (cheapest)...
# ❌ ERROR: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# 💡 DIAGNOSIS: Account ran out of credits!
#    → Add payment method at: https://platform.openai.com/account/billing
#
# ...
